# %%
import sys
import platform
print(f"Hola José. Estás corriendo Python {sys.version.split()[0]}")
print(f"Sistema Operativo: {platform.system()} {platform.release()}")
# Out:
# Hola José. Estás corriendo Python 3.14.2
# Sistema Operativo: Linux 6.14.0-37-generic
